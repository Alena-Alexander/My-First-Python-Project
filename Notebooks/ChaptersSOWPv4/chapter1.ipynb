# %% [markdown]
# # Introduction to Computers and programming
# ### Introduction 1.1
#
# Computers perform such a wide variety of tasks because they can\
# be programmed to. This means that computers are not designed to do just\
# one job, but to do any job that their program tells them to do.
#
# A program is a set of instructions that a computer follows to perform task\
# Microsoft Word and PowerPoint are 2 commonly used programs.\
# Programs are commonly referred to as software. All the software that we\
# use to make our computers useful are created by individuals working asprogrammers\
# or software developers.
#
# A programmer or software developer, is a person with the training and skills\
# necessary to design, create, and test computer programs.
#
#
# ### Hardware and Software 1.2
#
# The physical devices of which a computer is made are referred to as the\
# computers' hardware. The programs that run on the computer are\
# referred to as software.
#
# The term hardware refers to all the physical devices, or  components, of\
# which a computer is made. A computer is not a single device but a system of devices\
# that all work together.
#
# A typical computer system consists of the following major components:
#
# - A central processing unit(CPU)
# - Main memory
# - secondary storage devices
# - output devices
# - input devices
#
#
# ### The CPU
#
# When a computer is performing the tasks that a program tells it to do,\
# we say that the computer is running or executing the program. The\
# central processing unit, or CPU, is the part of the computer that\
# actually runs the programs.
#
# The CPU is the most important component in a computer  because without it\
# the computer would not run software.
#
# CPUs are all small chips known as microprocessors.
#
#
# ### Main memory
#
# You can think of main memory as the computers' work area.\
# This is where the computer stores a program while the program is running,\
# as well as the data the program is working with.
#
# ###  Secondary Storage device
#
# Secondary Storage is a type of memory that can hold data for long periods of time,\
# even when there is no power to the computer. Programs are normally stored in secondary\
# memory and loaded into main memory as needed. Important data, such as word processing documents,\
# payroll data, and inventory records, is saved in secondary storage as well.
#
# The most common type of secondary storage device is the disk drive.\
# A traditional disk drive stores data by magnetically encoding it\
# onto a spinning circular disk.
#
# External storage devices, which connect to one of the computers' communication ports,\
# are also available. External storage devices can be used to create backup\
# copies of important data or to move data to another computer.
#
# For example:
#
# USB drives are small devices tha plug into the computers' USB port and\
# appear to the system as a disk drive. These drives do not actually contain\
# a disk , however, the store data in a special type of memory known as flash memory.
#
# ### Input devices
#
# Input is any data the computer collects from people and from other devices.\
# The component that collects data and sends it to the computer is called an input device.\
# Common input devices are keyboard, mouse, touchscreen, scanner, microphone, and digital cam.
#
# ### Output devices
#
# Output is any data the computer produces for people or for other devices.\
# It might be a sales report, a list of names, or a graphic image.\
# The data is sent to an output device, which formats and presents it.
#
# ### Software
#
# Everything a computer does from the time you turn the power switch on until you\
# shut the system down, is under the control of software
#
# ### System software
#
# The programs that control and manage the basic operations of a computer are\
# referred to as system software. System software typically includes\
# the following types of programs:
#
# - Operating Systems
#
# An Operating System is the most fundamental set of programs on a computer.\
# The operating system controls the internal operations of the computers hardware,\
# manages all the devices connected to the computer, allows data to be saved to and retrieved\
# from storage devices and allows other programs to run on the computer.
#
# - Utility Programs
#
# A Utility Program performs a specialized task that enhances the computers'\
# operation or safeguards data.
#
# For example: virus scanners.
#
# - Software Development Tools
#
# Software Development Tools are the programs that programmers use to create,modify,\
# and test software.
#
# Assemblers, Compilers, and interpreters are good examples of them.
#
# ### How computers store data 1.3
#
# A computers memory is divided into tiny storage locations known as bytes.\
# One byte is enough memory to store a letter of the alphabet or a small number.\
# In order to do anything meaningful, a computer has to have lots of bytes.
#
# Each byte is divided into eight smaller storage known as bits.\
# The term bit stands for binary digit.
#
# When data is stored in a byte, the computer sets the eight bits to an on/off pattern\
# that represents the data.
#
# Depending on whether the bit is turned on or off, it can represent one or two different values.\
# In computer systems, a bit that is turned off represents the number 0, and a bit that\
# is turned on represents the number 1.
#
# This corresponds to the binary numbering system.\
# In binary numbering system all numeric values are written as sequences of 0s and 1s.
#
# Example:
# 10011101 = 157
#
# The position of each digit in a binary number has a value assigned to it.\
# Starting with the right most digit and moving left, the position values 2**0, 2**1, 2**2,\
#  2**3, and so forth, as shown.
#
# To determine the values of a binary number you simply add up the position\
# values of all the 1s, the sum is the value.
#
# ### Storing Characters
#
# Any piece of data that is in a computer's memory must be stored as\
# a binary number. When a character is stored it is first converted into\
# numeric code, and is then stored as memory. Over the year different coding\
# schemes have been developed to represent characters in computer memory.
#
# The most important of these coding schemes is ASCII. ASCII is a set of\
# 128 numeric codes that represent the English letters, various punctuation marks,\
# and other characters. ASCII is limited because it defines codes for only 128 characters.\
# To remedy this, the unicode character set was developed in the early 1990s.
#
# Unicode is an extensive encoding scheme that is compatible with ASCII\
# but can also represent characters for many of the languages in the world.\
# Today, Unicode is quickly becoming the standard character set used in the\
# computers' industry.
#
# ### Advanced Number Storage
#
# Negative numbers and real numbers cannot be represented using the simple binary\
# numbering technique we discussed. Computers are able to store negative numbers\
# and real numbers in memory, but to do so they use encoding schemes along with the\
# binary numbering system. Negative numbers are encoded using a technique known as\
# two's complement, and real numbers are encoded in floating point notation.\
# (You don't need to know how these encoding systems work)
#
# ### Other types of data
#
# Computers are often referred to as digital devices. The term digital can be used\
# to describe anything that uses binary numbers. Digital data is data that is stored\
# in binary format, and a digital device is any device that works with binary data.
#
# ### How a Program Works
#
# A computer's CPU can only understand instructions that are written in machine language.
# Because people find it very difficult to write entire programs in machine language
#  other programming languages have been invented.
#
# Earlier we stated the CPU is the most important component in a computer because
# it is the part of the computer that runs programs. Somtimes the CPU is called
# the computers' brain and is described as being smart. A CPU is an electronic device
# that is designed to do specific things.
#
# In particular the CPU is designed to do the following:
#
# - Reading a piece of data from the main memory
# - Adding two numbers
# - Subtracting one number from another number
# - Multiplying two numbers
# - Dividing one number by another number
# - Moving a piece of data from one memory location to another
# - Determine whether one value is equal to another value
#
# The CPU performs simple operations on pieces of data. The CPU does nothing on\
# its own, however. It has to be told what to do, and that's the purpose of a program.\
# A program is nothing more than a list of instructions that cause the CPU to perform operations.
#
# Here is an example of said instructions:
# 10110000
#
# When a CPU executes the instructions in a program, it is engaged in a
# process that is known as the fetch-decode-execute cycle.
#
# This cycle which consist of three steps, is repeated for each\
# instruction in the program. The steps are:
#
# - **Fetch**. A program is a long sequence of instructions. The first step of the\
# cycle is to fetch, or read, the next instruction from memory into the CPU.
#
# - **Decode**. A machine language instruction is a binary number represents a command\
# that tells the CPU to perform an operation.
#
# In this step, the CPU decodes the instruction that was just fetched from memory,
# to determine it should perform.
#
# - **Execute**. The last in the cycle is to execute, or perform, the operation.\
#
# ### From Machine Language to Assembly Language
#
# Computers can only execute programs that are written in machine language. As\
# previously mentioned a program can have thousands or even millions of binary instructions,\
# and writing such a program would be very tedious and time-consuming. Programming\
# in machine language would also be very difficult, because putting a 0 or a 1 in the\
# wrong place will cause an error. Although a computers' CPU only understands machine language,\
# it is impractical for people to write programs in machine language.
#
# For this reason, assembly language was created in the early days of computing as an\
# alternative to machine language. Instead of using binary numbers for instructions,\
# assembly languages uses short words that are known mnemonics.
#
# For example, in assembly language, the mnemonics **add** typically adds numbers,\
# **mul** typically multiplies numbers, and **mov** typically means to move a value\
# to a location in memory.
#
# The CPU only understands machine language, so a special program known as assembler\
# is used to translate an assembly language program to a machine language program.
#
# ### High-Level Languages
#
# Although assembly language makes it unnecessary to write binary machine language\
# instructions, it is not without difficulties.
#
# Assembly language is primarily a direct substitute for machine language, and like\
# machine language, it requires that you know alot about the CPU. Assembly language\
# also requires that write a large number of instructions for even the simplests programs.\
# Because assembly language is so close in nature to machine language it is referred to as\
# low-level languages. In the 1950s, a new generation of programming languages known\
# as high-level languages began to appear.
#
# A high-level language allows you to create powerful and complex programs without\
# knowing the CPU works and without writing
#
# large numbers of low-level instructions. In addition, most high-level languages\
# use words that easy to understand.
#
# Python is a modern, high-level programming language that we will use.\
# In Python, you would display the message Hello World with the following\
# on the computer screen:
#
# print("Hello World")
#
#
# ### Keywords, Operators, and Syntax: An Overview
#
# Each high-level language has its own set of predefined words that the programmer\
# must use to write a program. The words that make up a high-level programming language\
# are known as keywords or reserved words.
#
# Each key word has a specific meaning, and cannot be used for any other purpose.
#
# In addition to keywords, programming languages have operators that perform various\
# operations on data.
#
# For example, all programming languages have math operators that perform arithmetic.\
# In Python, as well as other languages, the + sign is an operator that adds two numbers.
#
# In addition to keywords and operators, each language has their own syntax,\
# which is a set of rules we must follow when writing a program.\
# syntax dictates how keywords and operators must be used in a program.
#
# The individual instructions that you use to write in a high-level programming language\
# are called statement. A programming statement can consist of keywords, operators, punctuation,\
# and other allowable programming elements, arranged in the proper sequence to perform an operation.
#
# ###  Compilers and Interpreters
#
# A compiler is a program that translates a high level language into a separate machine\
# language program. The machine language program can be executed anytime it is needed.
#
# An interpreter is a program that both translater and executes the instructions in a\
# high-level language program. As the interpreter reads the instructions, it converts it\
# to machine language then executes it.
#
# The statements that a programmer writes in a high-level language is called code\
# or source code. Typically, the programmer types a code into a text editor then\
# saves the code in a file on the computers' disk.
#
# Next the programmer uses a compiler or an interpreter to translate and execute the code.
#
# A syntax error is a mistake such as a misspelled key word or a missing punctuation\
# character. When this happens, the compiler or interpreter displays an error message.
#
# ### Using Python 1.5
# ### Installing Python
#
# Before you can try any of the programs shown in this book, or write ant of your own,\
# you need to make sure that Python is installed on your computer and properly configured.
#
# ### The Python Interpreter
#
# When you install python your computer, one of the items that is installed is\
# the Python interpreter. The Python interpreter is a program that can read Python\
# programming statements and executes them.
#
#  The interpreter has two mode: interactive mode and script mode. In interactive mode,\
#  interpreter waits for you to type Python statements on the keyboard.\
#  The interpreter then executes it then waits for you to type another statements.\
#  In script mode, interpreter reads the contents of a file that contains Python statements.
#
# ### Interactive Mode
#
# Once Python has been installed and set up on your system, you start the interpreter in\
# interactive mode by going to the operating systems' command line and typing\
# the following command:
#
#
# If you are using windows you can alternatively type python in the windows search box.\
# In the search results you will see a program called Python 3.5 clicking it will start\
# the interpreter in interactive mode.
#
# When the Python interpreter starts in interactive mode you will see the following\
# on the screen:
#
# ```
# Pytho 3.5.1 (v3.5.1: 37a07cee5969, Dec 6 2015, 01:38:48)
# [MSC v.1900 32 bit (intel)] on win32
# Type "help", "copyright", "credits" or "license"
# for more information.
# >>>
# ```
#
# The >>> that you see indicates the interpreter is waiting for you to type a\
# Python statement. After typing the statement, you press the enter key, and the\
# Python interpreter executes the statement. After the statement is executed on the\
# screen the >>> appears again indicating that the interpreter is waiting for you\
# to enter the next statement.
#
# ### Writing Python Programs and Running Them in Script Mode
#
# Although interactive mode is useful for testing code, the statements that you enter\
# in interactive mode are not saved as a program. They're simply executed and their results\
# are displayed on screen. if you want to save a set of Python statements as a program, you\
# must save them in a file.
#
# When you save a Python program, you  give it a name that ends with the .py extension\
# which identifies it as a Python program. For example,  you might save the program\
# previously shown with name test.py. To run the program, you would go to the directory\
# in which the file is saved and type the following command in the operating system:
#
# ```
# pyhton test.py
# ```
#
# Causing it to execute the statements in test.py.
#
# ### the IDLE Programming Environment
# Previously you learned how the python interpreter can be starred in interactive\
# mode at the operating system command line. As an alternative you can use an integrated\
# development environment(IDLE), which is a single program that gives you all the tools\
# you need to write, execute, and test a program.
#
# IDLE is automatically installed when Python language is installed. IDLE has a built-in text\
# editor with features specifically designed to help you write Python programs.
